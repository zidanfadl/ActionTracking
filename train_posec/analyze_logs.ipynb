# %%
import os 
HOME = os.getcwd()
print(HOME)
# Out:
# /media/ciis/680d5156-2214-4b41-baf0-6bb993bff707/ciis-compnew/Documents/ActionTracking/train_posec

# %%
logFolder = "ciis_21_v4"
# work_dirs/ciis_21_v4/ciis_21_v4_modified.json
jsonFile = "ciis_21_v4_modified"

# %%
# !python ../analysis_tools/analyze_logs_modified.py plot_curve ../work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys loss \
    --title "loss terhadap epoch" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[1]}.svg
# Out:
# plot curve of ../work_dirs/ciis_21_v4/ciis_21_v4_modified.json, metric is loss
# Traceback (most recent call last):
#   File "../analysis_tools/analyze_logs_modified.py", line 228, in <module>
#     main()
#   File "../analysis_tools/analyze_logs_modified.py", line 224, in main
#     eval(args.task)(log_dicts, args)
#   File "../analysis_tools/analyze_logs_modified.py", line 84, in plot_curve
#     plt.plot(xs, ys, label=legend[i * num_metrics + j], linewidth=0.5)
#   File "/home/ciis/miniconda3/envs/realtime/lib/python3.8/site-packages/matplotlib/pyplot.py", line 2812, in plot
#     return gca().plot(
#   File "/home/ciis/miniconda3/envs/realtime/lib/python3.8/site-packages/matplotlib/axes/_axes.py", line 1688, in plot
#     lines = [*self._get_lines(*args, data=data, **kwargs)]
#   File "/home/ciis/miniconda3/envs/realtime/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 311, in __call__
#     yield from self._plot_args(
#   File "/home/ciis/miniconda3/envs/realtime/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 504, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (1369,) and (1383,)

# %%
# !python analysis_tools/analyze_logs_modified.py plot_curve work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys acc/top1 \
    --title "akurasi top-1 terhadap checkpoint" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[2]}.svg
# Out:
# plot curve of work_dirs/ciis_10_best-550/lr-0d0482_loss-0d0099_top1-0d9072_top5-0d9894_mean1-0d9003.json, metric is acc/top1
# save curve to: work_dirs/ciis_10_best-550/best-550_top1-0d9072.svg

# %%
# !python analysis_tools/analyze_logs_modified.py plot_curve work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys acc/top5 \
    --title "akurasi top-5 terhadap checkpoint" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[3]}.svg
# Out:
# plot curve of work_dirs/ciis_10_best-550/lr-0d0482_loss-0d0099_top1-0d9072_top5-0d9894_mean1-0d9003.json, metric is acc/top5
# save curve to: work_dirs/ciis_10_best-550/best-550_top5-0d9894.svg

# %%
# !python analysis_tools/analyze_logs_modified.py plot_curve work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys acc/mean1 \
    --title "akurasi rata-rata terhadap checkpoint" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[4]}.svg
# Out:
# plot curve of work_dirs/ciis_10_best-550/lr-0d0482_loss-0d0099_top1-0d9072_top5-0d9894_mean1-0d9003.json, metric is acc/mean1
# save curve to: work_dirs/ciis_10_best-550/best-550_mean1-0d9003.svg

# %%
# !python analysis_tools/analyze_logs_modified.py plot_curve work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys lr \
    --title "lr terhadap epoch" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[0]}.svg
# Out:
# plot curve of work_dirs/ciis_10_best-550/lr-0d0482_loss-0d0099_top1-0d9072_top5-0d9894_mean1-0d9003.json, metric is lr
# save curve to: work_dirs/ciis_10_best-550/best-550_lr-0d0482.svg
