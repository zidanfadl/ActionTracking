# %%
import os 
HOME = os.getcwd()
print(HOME)
# Out:
# /media/ciis/680d5156-2214-4b41-baf0-6bb993bff707/ciis-compnew/Documents/ActionTracking

# %%
logFolder = "ciis_21_v5"
jsonFile = "20250602_134700_modified"

# %%
print(f'work_dirs/{logFolder}/{jsonFile + ".json"}')
# Out:
# work_dirs/ciis_21_v5/20250602_134700_modified.json

# %%
# !python analysis_tools/analyze_logs_modified.py plot_curve work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys loss \
    --title "loss terhadap epoch" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[1]}.svg
# Out:
# Traceback (most recent call last):
#   File "analysis_tools/analyze_logs_modified.py", line 228, in <module>
#     main()
#   File "analysis_tools/analyze_logs_modified.py", line 222, in main
#     log_dicts = load_json_logs(json_logs)
#   File "analysis_tools/analyze_logs_modified.py", line 156, in load_json_logs
#     with open(json_log, 'r') as log_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'work_dirs/ciis_21_v5/20250602_134700_modified.json'

# %%
# !python analysis_tools/analyze_logs_modified.py plot_curve work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys acc/top1 \
    --title "akurasi top-1 terhadap checkpoint" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[2]}.svg
# Out:
# plot curve of work_dirs/ciis_21_v5//20250602_134700/vis_data/20250602_134700_modified.json, metric is acc/top1
# save curve to: work_dirs/ciis_21_v5/v5_data/20250602.svg
# Traceback (most recent call last):
#   File "analysis_tools/analyze_logs_modified.py", line 228, in <module>
#     main()
#   File "analysis_tools/analyze_logs_modified.py", line 224, in main
#     eval(args.task)(log_dicts, args)
#   File "analysis_tools/analyze_logs_modified.py", line 92, in plot_curve
#     plt.savefig(args.out)
#   File "/home/ciis/miniconda3/envs/realtime/lib/python3.8/site-packages/matplotlib/pyplot.py", line 1023, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "/home/ciis/miniconda3/envs/realtime/lib/python3.8/site-packages/matplotlib/figure.py", line 3378, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/ciis/miniconda3/envs/realtime/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2366, in print_figure
#     result = print_method(
# ...

# %%
# !python analysis_tools/analyze_logs_modified.py plot_curve work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys acc/top5 \
    --title "akurasi top-5 terhadap checkpoint" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[3]}.svg
# Out:
# plot curve of work_dirs/ciis_21-2/20250310_130346/vis_data/20250310_130346_modified.json, metric is acc/top5
# save curve to: work_dirs/ciis_21-2/21-2_130346.svg

# %%
# !python analysis_tools/analyze_logs_modified.py plot_curve work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys acc/mean1 \
    --title "akurasi rata-rata terhadap checkpoint" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[4]}.svg
# Out:
# plot curve of work_dirs/ciis_21-2/20250310_130346/vis_data/20250310_130346_modified.json, metric is acc/mean1
# save curve to: work_dirs/ciis_21-2/21-2_modified.svg

# %%
# !python analysis_tools/analyze_logs_modified.py plot_curve work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys lr \
    --title "lr terhadap epoch" \
    --out work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[0]}.svg
# Out:
# plot curve of work_dirs/ciis_21-2/20250310_130346/vis_data/20250310_130346_modified.json, metric is lr
# save curve to: work_dirs/ciis_21-2/21-2_20250310.svg
