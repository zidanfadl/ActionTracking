# %%
import os 
HOME = os.getcwd()
print(HOME)
# Out:
# /media/ciis/680d5156-2214-4b41-baf0-6bb993bff707/ciis-compnew/Documents/ActionTracking/train_posec

# %%
logFolder = "ciis_21-v5"
# work_dirs/ciis_21_v4/ciis_21_v4_modified.json
jsonFile = "20250602_134700_modified"

#rename the json file like this
#lr-0d0482_loss-0d0099_top1-0d9072_top5-0d9894_mean1-0d9003
jsonFile = "lr-0d0451_loss-0d1446_top1-0d6701_top5-0d9696_mean1-0d4650"

# %%
# !python ../analysis_tools/analyze_logs_modified.py plot_curve ../work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys loss \
    --title "loss terhadap epoch" \
    --out ../work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[1]}.svg
# Out:
# plot curve of ../work_dirs/ciis_21-v5/20250602_134700_modified.json, metric is loss
# save curve to: ../work_dirs/ciis_21-v5/21-v5_134700.svg

# %%
# !python ../analysis_tools/analyze_logs_modified.py plot_curve ../work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys acc/top1 \
    --title "akurasi top-1 terhadap checkpoint" \
    --out ../work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[2]}.svg
# Out:
# plot curve of ../work_dirs/ciis_21-v5/20250602_134700_modified.json, metric is acc/top1
# save curve to: ../work_dirs/ciis_21-v5/21-v5_modified.svg

# %%
# !python ../analysis_tools/analyze_logs_modified.py plot_curve ../work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys acc/top5 \
    --title "akurasi top-5 terhadap checkpoint" \
    --out ../work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[3]}.svg
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `python ../analysis_tools/analyze_logs_modified.py plot_curve ../work_dirs/{logFolder}/{jsonFile + ".json"}      --keys acc/top5      --title "akurasi top-5 terhadap checkpoint"      --out ../work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[3]}.svg'

# %%
# !python ../analysis_tools/analyze_logs_modified.py plot_curve ../work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys acc/mean1 \
    --title "akurasi rata-rata terhadap checkpoint" \
    --out ../work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[4]}.svg
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `python ../analysis_tools/analyze_logs_modified.py plot_curve ../work_dirs/{logFolder}/{jsonFile + ".json"}      --keys acc/mean1      --title "akurasi rata-rata terhadap checkpoint"      --out ../work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[4]}.svg'

# %%
# !python ../analysis_tools/analyze_logs_modified.py plot_curve ../work_dirs/{logFolder}/{jsonFile + ".json"} \
    --keys lr \
    --title "lr terhadap epoch" \
    --out ../work_dirs/{logFolder}/{(logFolder.split("_"))[-1]}_{(jsonFile.split("_"))[0]}.svg
# Out:
# plot curve of ../work_dirs/ciis_21-v5/20250602_134700_modified.json, metric is lr
# save curve to: ../work_dirs/ciis_21-v5/21-v5_20250602.svg
